# %% [markdown]
# # :gear: Installations
# List of installed and usd packages:
# - pyAgrum
# - pandas
# - numPy
# - matplotlib
# - scikit-learn

# %%
# %pip install pyagrum

# %%
# %pip install pandas

# %%
# %pip install numpy

# %%
# %pip install matplotlib

# %%
# %pip install scikit-learn
