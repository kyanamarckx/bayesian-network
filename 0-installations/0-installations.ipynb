# %% [markdown]
# # :gear: Installations
# List of installed and usd packages:
# - pyAgrum

# %%
# %pip install pyagrum
# Out:
# ...
#   Obtaining dependency information for pyagrum from https://files.pythonhosted.org/packages/17/bb/23d4fe01eb86fcdd90475d888617d1d2c42de5138208c620a279ca197556/pyagrum-2.3.2-cp310-abi3-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/ab/ca/feab00bd44aa5fe1ad2c18f08b4d3bb92e26484b0b1d1443897809ed528c/numpy-2.4.6-cp312-cp312-win_amd64.whl.metadata
# ...
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/04/a1/4571fc46e7702de8d0c2dc54ad1b2f8e29328dea3ee90831181f7353d93c/matplotlib-3.10.9-cp312-cp312-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      ----------------------------- -------- 41.0/52.8 kB 991.0 kB/s eta 0:00:01
#      ---------------------------------------- 52.8/52.8 kB 1.4 MB/s eta 0:00:00
# ...
